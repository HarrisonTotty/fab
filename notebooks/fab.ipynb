# %% [markdown]
# # Flesh and Blood Analysis Notebook

# %%
from fab import *

# %%
cards = CardList.load('~/work/csvs/card.csv')

# %%
cards[50]
# Out:
# Card(body='**Bravo Specialization** *(You may only have Crippling Crush in your deck if your hero is Bravo.)*\n\n**Crush** - If Crippling Crush deals 4 or more damage to a hero, they discard 2 random cards.', cost=7, defense=3, flavor_text=None, grants=[''], health=None, identifiers=['1HP050', 'WTR043'], intelligence=None, keywords=['Bravo Specialization', 'Crush', ''], name='Crippling Crush', pitch=1, power=11, rarities=['M', 'M'], sets=['1HP', 'WTR'], tags=[], type_text='Guardian Action – Attack', types=['Guardian', 'Action', 'Attack'])

# %%
cards.statistics()
# Out:
# {'count': 1383,
#  'max_cost': 10,
#  'max_defense': 7,
#  'max_health': 40,
#  'max_intelligence': 4,
#  'max_pitch': 3,
#  'max_power': 14,
#  'mean_cost': 1.3026204564666104,
#  'mean_defense': 2.525173611111111,
#  'mean_health': 26.170212765957448,
#  'mean_intelligence': 3.977777777777778,
#  'mean_pitch': 2.0176767676767677,
#  'mean_power': 4.203732503888025,
#  'median_cost': 1,
#  'median_defense': 3.0,
#  'median_health': 20,
#  'median_intelligence': 4,
#  'median_pitch': 2.0,
#  'median_power': 4,
#  'min_cost': 0,
#  'min_defense': 0,
#  'min_health': 6,
#  'min_intelligence': 3,
#  'min_pitch': 1,
#  'min_power': 0}

# %%
cards.filter(power=14)
# Out:
# CardList(items=[Card(body='**Heave 3** *(At the beginning of your end phase, if Pulverize is in your hand and you have an empty arsenal zone, you may pay {r}{r}{r} and put Pulverize face up into your arsenal. If you do, create 3 Seismic Surge tokens.)*\n\nIf Pulverize hits a hero, their first attack during their next turn has -4{p}.', cost=10, defense=3, flavor_text=None, grants=[''], health=None, identifiers=['EVR021'], intelligence=None, keywords=['Heave 3', ''], name='Pulverize', pitch=1, power=14, rarities=['M'], sets=['EVR'], tags=[], type_text='Guardian Action – Attack', types=['Guardian', 'Action', 'Attack'])])

# %%
cards.filter(types=['Shadow', 'Runeblade'])
# Out:
# CardList(items=[Card(body='Whenever you play a Runeblade card, if you have played another \'non-attack\' action card this turn, create a Runechant token. *(It\'s an aura with "When you play an attack action card or attack with a weapon, destroy Runechant and deal 1 arcane damage to target opposing hero.”)*', cost=None, defense=None, flavor_text=None, grants=[''], health=40, identifiers=['HER011', 'HER019', '1HP258', 'ARC075', 'CRU138'], intelligence=4, keywords=['', ''], name='Viserai, Rune Blood', pitch=None, power=None, rarities=['P', 'P', 'C', 'T', 'C'], sets=['HER', 'HER', '1HP', 'ARC', 'CRU'], tags=[], type_text='Runeblade Hero', types=['Runeblade', 'Hero']), Card(body='Whenever you play a Runeblade card, if you have played another \'non-attack\' action card this turn, create a Runechant token. *(It\'s an aura with "When you play an attack action card or attack with a weapon, destroy Runechant and deal 1 arcane damage to target opposing hero.”)*', cost=None, defense=None, flavor
# ...
