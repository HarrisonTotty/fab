# %% [markdown]
# # Flesh and Blood Analysis Notebook

# %%
from fab import *
cards = CardList.load('~/work/data/cards.json')
card_sets = CardSetCollection.load('~/work/data/card-sets.json')

# %%
cards[50].image()

# %%
cards.statistics()
# Out:
# {'count': 1383,
#  'max_cost': 10,
#  'max_defense': 7,
#  'max_health': 40,
#  'max_intelligence': 4,
#  'max_pitch': 3,
#  'max_power': 14,
#  'mean_cost': 1.3,
#  'mean_defense': 2.53,
#  'mean_health': 26.17,
#  'mean_intelligence': 3.98,
#  'mean_pitch': 2.02,
#  'mean_power': 4.2,
#  'median_cost': 1,
#  'median_defense': 3.0,
#  'median_health': 20,
#  'median_intelligence': 4,
#  'median_pitch': 2.0,
#  'median_power': 4,
#  'min_cost': 0,
#  'min_defense': 0,
#  'min_health': 6,
#  'min_intelligence': 3,
#  'min_pitch': 1,
#  'min_power': 0,
#  'stdev_cost': 1.34,
#  'stdev_defense': 0.85,
#  'stdev_health': 10.58,
#  'stdev_intelligence': 0.15,
#  'stdev_pitch': 0.82,
#  'stdev_power': 1.92,
#  'total_cost': 1541,
#  'total_defense': 2909,
#  'total_health': 1230,
#  'total_intelligence': 179,
#  'total_pitch': 2397,
#  'total_power': 2703}

# %%
cards.filter(power=14)[0].image()

# %%
cards.sets()
# Out:
# ['BRI',
#  'MON',
#  'HER',
#  'TEA',
#  '1HP',
#  'LXI',
#  'ELE',
#  'LEV',
#  'CHN',
#  'WTR',
#  'OLD',
#  'OXO',
#  'KSU',
#  'BOL',
#  'XXX',
#  'FAB',
#  'IRA',
#  'LSS',
#  'RVD',
#  'EVR',
#  'PSM',
#  'RNR',
#  'LGS',
#  'ARC',
#  'BVO',
#  'CRU',
#  'DVR']

# %%
cards.heroes().names()
# Out:
# ['Bravo, Star of the Show',
#  'Yorick, Weaver of Tales',
#  'Oldhim, Grandfather of Eternity',
#  'Prism',
#  'Kavdaen, Trader of Skins',
#  'Shiyana, Diamond Gemini',
#  'Lexi, Livewire',
#  'Dorinthea, Quicksilver Prodigy',
#  'Bravo, Showstopper',
#  'Azalea, Ace in the Hole',
#  'Kayo, Berserker Runt',
#  'Genis Wotchuneed',
#  'Chane',
#  'Bravo',
#  'Dorinthea',
#  'Katsu, the Wanderer',
#  'Ser Boltyn, Breaker of Dawn',
#  'Valda Brightaxe',
#  'Dorinthea Ironsong',
#  'Boltyn',
#  'Ruu’di, Gem Keeper',
#  'Rhinar',
#  'Briar',
#  'Chane, Bound by Shadow',
#  'Benji, the Piercing Wind',
#  'Ira, Crimson Haze',
#  'Lexi',
#  'Azalea',
#  'Prism, Sculptor of Arc Light',
#  'Briar, Warden of Thorns',
#  'Katsu',
#  'Kano',
#  'Oldhim',
#  'Kano, Dracai of Aether',
#  'Dash, Inventor Extraordinaire',
#  'Taylor',
#  'Data Doll MKII',
#  'Levia, Shadowborn Abomination',
#  'Rhinar, Reckless Rampage',
#  'Iyslander',
#  'Levia',
#  'Viserai, Rune Blood',
#  'Viserai',
#  'Dash',
# ...

# %%
cards.types()
# Out:
# ['Gem',
#  'Attack Reaction',
#  'Sword',
#  'Defense Reaction',
#  'Guardian',
#  'Legs',
#  'Orb',
#  'Flail',
#  'Wizard',
#  'Item',
#  'Illusionist',
#  'Axe',
#  'Token',
#  'Elemental',
#  'Arrow',
#  'Mechanologist',
#  'Pistol',
#  'Staff',
#  'Mentor',
#  'Landmark',
#  'Chest',
#  'Generic',
#  'Warrior',
#  'Gun',
#  'Light',
#  'Bard',
#  'Shapeshifter',
#  'Shadow',
#  'Hero',
#  'Ally',
#  'Earth',
#  'Arms',
#  'Ninja',
#  'Bow',
#  'Off-Hand',
#  'Scythe',
#  'Resource',
#  'Weapon',
#  'Action',
#  'Dagger',
#  'Ice',
#  'Ranger',
#  '1H',
#  'Trap',
#  'Scepter',
#  'Merchant',
#  'Young',
#  'Equipment',
#  'Club',
#  'Attack',
#  'Hammer',
#  'Aura',
#  'Brute',
#  'Instant',
#  '2H',
#  'Head',
#  'Runeblade',
#  'Claw',
#  'Demon',
#  'Lightning']

# %%
cards.defense_values()
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
cards.filter(defense=7)[0].image()

# %%
card_sets.get_release_date(cards.filter(name='Chane')[0])
# Out:
# datetime.date(2021, 5, 7)

# %%
cards[20]
# Out:
# Card(body='As an additional cost to play Breakneck Battery, discard a random card.\n\nIf the discarded card has 6 or more {p}, Breakneck Battery gains **go again**.', cost=2, defense=3, flavor_text=None, grants=[], health=None, identifiers=['1HP018', 'WTR013'], image_urls={'WTR013 – A': 'https://storage.googleapis.com/fabmaster/media/images/WTR_13.width-450.png', 'WTR013 – U': 'https://storage.googleapis.com/fabmaster/media/images/U-WTR13.width-450.png'}, intelligence=None, keywords=['Go again', ''], name='Breakneck Battery', pitch=3, power=4, rarities=['R', 'R'], sets=['1HP', 'WTR'], tags=[], type_text='Brute Action – Attack', types=['Brute', 'Action', 'Attack'])
