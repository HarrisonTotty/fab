# %% [markdown]
# # Import Flesh and Blood CSV Data

# %% [markdown]
# Here we'll import the data provided by [flesh-cube/flesh-and-blood-cards](https://github.com/flesh-cube/flesh-and-blood-cards) and convert it to our JSON format.

# %%
from fab import CardList, CardSetCollection
cards = CardList.load('~/work/csvs/card.csv', set_catalog=True)
card_sets = CardSetCollection.load('~/work/csvs/set.csv', set_catalog=True)

# %% [markdown]
# This block keeps track of upstream changes with respect to our pre-parsed data.

# %%
import os
if os.path.isfile(os.path.expanduser('~/work/data/cards.json')):
    old_cards = CardList.load('~/work/data/cards.json')
    old_hashes = {card.full_name: hash(card.to_json()) for card in old_cards}
    new_hashes = {card.full_name: hash(card.to_json()) for card in cards}
    added = 0
    updated = 0
    for nk, nv in new_hashes.items():
        if not nk in old_hashes:
            added += 1
            print(f'Added "{nk}".')
        elif nv != old_hashes[nk]:
            updated += 1
            print(f'Updated "{nk}".')
    print(f'Added {added} cards and updated {updated} cards.')
# Out:
# Updated "Heart of Fyendal (3)".
# Updated "Rhinar, Reckless Rampage".
# Updated "Rhinar".
# Updated "Romping Club".
# Updated "Scabskin Leathers".
# Updated "Barkbone Strapping".
# Updated "Alpha Rampage (1)".
# Updated "Bloodrush Bellow (2)".
# Updated "Reckless Swing (3)".
# Updated "Sand Sketched Plan (3)".
# Updated "Bone Head Barrier (2)".
# Updated "Breakneck Battery (1)".
# Updated "Breakneck Battery (2)".
# Updated "Breakneck Battery (3)".
# Updated "Savage Feast (1)".
# Updated "Savage Feast (2)".
# Updated "Savage Feast (3)".
# Updated "Barraging Beatdown (1)".
# Updated "Barraging Beatdown (2)".
# Updated "Barraging Beatdown (3)".
# Updated "Savage Swing (1)".
# Updated "Savage Swing (2)".
# Updated "Savage Swing (3)".
# Updated "Pack Hunt (1)".
# Updated "Pack Hunt (2)".
# Updated "Pack Hunt (3)".
# Updated "Smash Instinct (1)".
# Updated "Smash Instinct (2)".
# Updated "Smash Instinct (3)".
# Updated "Wrecker Romp (1)".
# Updated "Wrecker Romp (2)".
# Updated "Wrecker Romp (3)".
# Updated "Awakening Bellow (1)".
# Updated "Awakening Bellow (2)".
# Updated "Awakening Bellow (3)".
# Updated "Primeval Bellow (1)".
# Updated "Primeval Bellow (2)".
# Updated "Primeval Bellow (3)".
# Updated "Bravo, Showstopper".
# Updated "Bravo".
# Updated "Anothos".
# Updated "Tectonic Plating".
# Updated "Helm of Isen's Peak".
# Updated "Crippling Crush (1)".
# Updated "Spinal Crush (1)".
# Updated "Cranial Crush (3)".
# Updated "Forged for War (2)".
# Updated "Show Time! (3)".
# Updated "Disable (1)".
# Updated "Disable (2)".
# Updated "Disable (3)".
# Updated "Staunch Response (1)".
# Updated "Staunch Response (2)".
# Updated "Staunch Response (3)".
# Updated "Blessing of Deliverance (1)".
# Updated "Blessing of Deliverance (2)".
# Updated "Blessing of Deliverance (3)".
# Updated "Buckling Blow (1)".
# Updated "Buckling Blow (2)".
# Updated "Buckling Blow (3)".
# Updated "Cartilage Crush (1)".
# Updated "Cartilage Crush (2)".
# Updated "Cartilage Crush (3)".
# Updated "Crush Confidence (1)".
# Updated "Crush Confidence (2)".
# Updated "Crush Confidence (3)".
# Updated "Debilitate (1)".
# Updated "Debilitate (2)".
# Updated "Debilitate (3)".
# Updated "Emerging Power (1)".
# Updated "Emerging Power (2)".
# Updated "Emerging Power (3)".
# Updated "Stonewall Confidence (1)".
# Updated "Stonewall Confidence (2)".
# Updated "Stonewall Confidence (3)".
# Updated "Seismic Surge".
# Updated "Katsu, the Wanderer".
# Updated "Katsu".
# Updated "Harmonized Kodachi".
# Updated "Mask of Momentum".
# Updated "Breaking Scales".
# Updated "Lord of Wind (3)".
# Updated "Ancestral Empowerment (1)".
# Updated "Mugenshi: RELEASE (2)".
# Updated "Hurricane Technique (2)".
# Updated "Pounding Gale (1)".
# Updated "Fluster Fist (1)".
# Updated "Fluster Fist (2)".
# Updated "Fluster Fist (3)".
# Updated "Blackout Kick (1)".
# Updated "Blackout Kick (2)".
# Updated "Blackout Kick (3)".
# Updated "Flic Flak (1)".
# Updated "Flic Flak (2)".
# Updated "Flic Flak (3)".
# Updated "Open the Center (1)".
# Updated "Open the Center (2)".
# Updated "Open the Center (3)".
# Updated "Head Jab (1)".
# Updated "Head Jab (2)".
# Updated "Head Jab (3)".
# Updated "Leg Tap (1)".
# Updated "Leg Tap (2)".
# Updated "Leg Tap (3)".
# Updated "Rising Knee Thrust (1)".
# Updated "Rising Knee Thrust (2)".
# Updated "Rising Knee Thrust (3)".
# Updated "Surging Strike (1)".
# Updated "Surging Strike (2)".
# Updated "Surging Strike (3)".
# Updated "Whelming Gustwave (1)".
# Updated "Whelming Gustwave (2)".
# Updated "Whelming Gustwave (3)".
# Updated "Dorinthea Ironsong".
# Updated "Dorinthea".
# Updated "Dawnblade".
# Updated "Braveforge Bracers".
# Updated "Refraction Bolters".
# Updated "Glint the Quicksilver (3)".
# Updated "Steelblade Supremacy (1)".
# Updated "Rout (1)".
# Updated "Singing Steelblade (2)".
# Updated "Ironsong Determination (2)".
# Updated "Overpower (1)".
# Updated "Overpower (2)".
# Updated "Overpower (3)".
# Updated "Steelblade Shunt (1)".
# Updated "Steelblade Shunt (2)".
# Updated "Steelblade Shunt (3)".
# Updated "Warrior's Valor (1)".
# Updated "Warrior's Valor (2)".
# Updated "Warrior's Valor (3)".
# Updated "Ironsong Response (1)".
# Updated "Ironsong Response (2)".
# Updated "Ironsong Response (3)".
# Updated "Biting Blade (1)".
# Updated "Biting Blade (2)".
# Updated "Biting Blade (3)".
# Updated "Stroke of Foresight (1)".
# Updated "Stroke of Foresight (2)".
# Updated "Stroke of Foresight (3)".
# Updated "Sharpen Steel (1)".
# Updated "Sharpen Steel (2)".
# Updated "Sharpen Steel (3)".
# Updated "Driving Blade (1)".
# Updated "Driving Blade (2)".
# Updated "Driving Blade (3)".
# Updated "Nature's Path Pilgrimage (1)".
# Updated "Nature's Path Pilgrimage (2)".
# Updated "Nature's Path Pilgrimage (3)".
# Updated "Fyendal's Spring Tunic".
# Updated "Hope Merchant's Hood".
# Updated "Heartened Cross Strap".
# Updated "Goliath Gauntlet".
# Updated "Snapdragon Scalers".
# Updated "Ironrot Helm".
# Updated "Ironrot Plate".
# Updated "Ironrot Gauntlet".
# Updated "Ironrot Legs".
# Updated "Enlightened Strike (1)".
# Updated "Tome of Fyendal (2)".
# Updated "Last Ditch Effort (3)".
# Updated "Crazy Brew (3)".
# Updated "Remembrance (2)".
# Updated "Drone of Brutality (1)".
# Updated "Drone of Brutality (2)".
# Updated "Drone of Brutality (3)".
# Updated "Snatch (1)".
# Updated "Snatch (2)".
# Updated "Snatch (3)".
# Updated "Energy Potion (3)".
# Updated "Potion of Strength (3)".
# Updated "Timesnap Potion (3)".
# Updated "Sigil of Solace (1)".
# Updated "Sigil of Solace (2)".
# Updated "Sigil of Solace (3)".
# Updated "Barraging Brawnhide (1)".
# Updated "Barraging Brawnhide (2)".
# Updated "Barraging Brawnhide (3)".
# Updated "Demolition Crew (1)".
# Updated "Demolition Crew (2)".
# Updated "Demolition Crew (3)".
# Updated "Flock of the Feather Walkers (1)".
# Updated "Flock of the Feather Walkers (2)".
# Updated "Flock of the Feather Walkers (3)".
# Updated "Nimble Strike (1)".
# Updated "Nimble Strike (2)".
# Updated "Nimble Strike (3)".
# Updated "Raging Onslaught (1)".
# Updated "Raging Onslaught (2)".
# Updated "Raging Onslaught (3)".
# Updated "Scar for a Scar (1)".
# Updated "Scar for a Scar (2)".
# Updated "Scar for a Scar (3)".
# Updated "Scour the Battlescape (1)".
# Updated "Scour the Battlescape (2)".
# Updated "Scour the Battlescape (3)".
# Updated "Regurgitating Slog (1)".
# Updated "Regurgitating Slog (2)".
# Updated "Regurgitating Slog (3)".
# Updated "Wounded Bull (1)".
# Updated "Wounded Bull (2)".
# Updated "Wounded Bull (3)".
# Updated "Wounding Blow (1)".
# Updated "Wounding Blow (2)".
# Updated "Wounding Blow (3)".
# Updated "Pummel (1)".
# Updated "Pummel (2)".
# Updated "Pummel (3)".
# Updated "Razor Reflex (1)".
# Updated "Razor Reflex (2)".
# Updated "Razor Reflex (3)".
# Updated "Unmovable (1)".
# Updated "Unmovable (2)".
# Updated "Unmovable (3)".
# Updated "Sink Below (1)".
# Updated "Sink Below (2)".
# Updated "Sink Below (3)".
# Updated "Nimblism (1)".
# Updated "Nimblism (2)".
# Updated "Nimblism (3)".
# Updated "Sloggism (1)".
# Updated "Sloggism (2)".
# Updated "Sloggism (3)".
# Updated "Cracked Bauble (2)".
# Updated "Quicken".
# Updated "Eye of Ophidia (3)".
# Updated "Dash, Inventor Extraordinaire".
# Updated "Dash".
# Updated "Teklo Plasma Pistol".
# Updated "Teklo Foundry Heart".
# Updated "Achilles Accelerator".
# Updated "High Octane (1)".
# Updated "Teklo Core (3)".
# Updated "Maximum Velocity (1)".
# Updated "Spark of Genius (2)".
# Updated "Induction Chamber (1)".
# Updated "Pedal to the Medal (1)".
# Updated "Pedal to the Medal (2)".
# Updated "Pedal to the Medal (3)".
# Updated "Pour the Mold (1)".
# Updated "Pour the Mold (2)".
# Updated "Pour the Mold (3)".
# Updated "Aether Sink (2)".
# Updated "Cognition Nodes (3)".
# Updated "Convection Amplifier (1)".
# Updated "Over Loop (1)".
# Updated "Over Loop (2)".
# Updated "Over Loop (3)".
# Updated "Throttle (1)".
# Updated "Throttle (2)".
# Updated "Throttle (3)".
# Updated "Zero to Sixty (1)".
# Updated "Zero to Sixty (2)".
# Updated "Zero to Sixty (3)".
# Updated "Zipper Hit (1)".
# Updated "Zipper Hit (2)".
# Updated "Zipper Hit (3)".
# Updated "Locked and Loaded (1)".
# Updated "Locked and Loaded (2)".
# Updated "Locked and Loaded (3)".
# Updated "Dissipation Shield (2)".
# Updated "Hyper Driver (1)".
# Updated "Optekal Monocle (3)".
# Updated "Azalea, Ace in the Hole".
# Updated "Azalea".
# Updated "Death Dealer".
# Updated "Skullbone Crosswrap".
# Updated "Bull's Eye Bracers".
# Updated "Red in the Ledger (1)".
# Updated "Three of a Kind (1)".
# Updated "Endless Arrow (1)".
# Updated "Nock the Deathwhistle (3)".
# Updated "Rapid Fire (2)".
# Updated "Take Cover (1)".
# Updated "Take Cover (2)".
# Updated "Take Cover (3)".
# Updated "Silver the Tip (1)".
# Updated "Silver the Tip (2)".
# Updated "Silver the Tip (3)".
# Updated "Take Aim (1)".
# Updated "Take Aim (2)".
# Updated "Take Aim (3)".
# Updated "Head Shot (1)".
# Updated "Head Shot (2)".
# Updated "Head Shot (3)".
# Updated "Hamstring Shot (1)".
# Updated "Hamstring Shot (2)".
# Updated "Hamstring Shot (3)".
# Updated "Ridge Rider Shot (1)".
# Updated "Ridge Rider Shot (2)".
# Updated "Ridge Rider Shot (3)".
# Updated "Salvage Shot (1)".
# Updated "Salvage Shot (2)".
# Updated "Salvage Shot (3)".
# Updated "Searing Shot (1)".
# Updated "Searing Shot (2)".
# Updated "Searing Shot (3)".
# Updated "Sic 'Em Shot (1)".
# Updated "Sic 'Em Shot (2)".
# Updated "Sic 'Em Shot (3)".
# Updated "Viserai, Rune Blood".
# Updated "Viserai".
# Updated "Nebula Blade".
# Updated "Grasp of the Arknight".
# Updated "Crown of Dichotomy".
# Updated "Arknight Ascendancy (1)".
# Updated "Mordred Tide (1)".
# Updated "Ninth Blade of the Blood Oath (2)".
# Updated "Become the Arknight (3)".
# Updated "Tome of the Arknight (3)".
# Updated "Spellblade Assault (1)".
# Updated "Spellblade Assault (2)".
# Updated "Spellblade Assault (3)".
# Updated "Reduce to Runechant (1)".
# Updated "Reduce to Runechant (2)".
# Updated "Reduce to Runechant (3)".
# Updated "Oath of the Arknight (1)".
# Updated "Oath of the Arknight (2)".
# Updated "Oath of the Arknight (3)".
# Updated "Amplify the Arknight (1)".
# Updated "Amplify the Arknight (2)".
# Updated "Amplify the Arknight (3)".
# Updated "Drawn to the Dark Dimension (1)".
# Updated "Drawn to the Dark Dimension (2)".
# Updated "Drawn to the Dark Dimension (3)".
# Updated "Rune Flash (1)".
# Updated "Rune Flash (2)".
# Updated "Rune Flash (3)".
# Updated "Spellblade Strike (1)".
# Updated "Spellblade Strike (2)".
# Updated "Spellblade Strike (3)".
# Updated "Bloodspill Invocation (1)".
# Updated "Bloodspill Invocation (2)".
# Updated "Bloodspill Invocation (3)".
# Updated "Read the Runes (1)".
# Updated "Read the Runes (2)".
# Updated "Read the Runes (3)".
# Updated "Runechant".
# Updated "Kano, Dracai of Aether".
# Updated "Kano".
# Updated "Crucible of Aetherweave".
# Updated "Storm Striders".
# Updated "Robe of Rapture".
# Updated "Blazing Aether (1)".
# Updated "Sonic Boom (2)".
# Updated "Forked Lightning (1)".
# Updated "Lesson in Lava (2)".
# Updated "Tome of Aetherwind (1)".
# Updated "Absorb in Aether (1)".
# Updated "Absorb in Aether (2)".
# Updated "Absorb in Aether (3)".
# Updated "Aether Spindle (1)".
# Updated "Aether Spindle (2)".
# Updated "Aether Spindle (3)".
# Updated "Stir the Aetherwinds (1)".
# Updated "Stir the Aetherwinds (2)".
# Updated "Stir the Aetherwinds (3)".
# Updated "Aether Flare (1)".
# Updated "Aether Flare (2)".
# Updated "Aether Flare (3)".
# Updated "Index (1)".
# Updated "Index (2)".
# Updated "Index (3)".
# Updated "Reverberate (1)".
# Updated "Reverberate (2)".
# Updated "Reverberate (3)".
# Updated "Scalding Rain (1)".
# Updated "Scalding Rain (2)".
# Updated "Scalding Rain (3)".
# Updated "Zap (1)".
# Updated "Zap (2)".
# Updated "Zap (3)".
# Updated "Voltic Bolt (1)".
# Updated "Voltic Bolt (2)".
# Updated "Voltic Bolt (3)".
# Updated "Arcanite Skullcap".
# Updated "Talismanic Lens".
# Updated "Vest of the First Fist".
# Updated "Bracers of Belief".
# Updated "Mage Master Boots".
# Updated "Nullrune Hood".
# Updated "Nullrune Robe".
# Updated "Nullrune Gloves".
# Updated "Nullrune Boots".
# Updated "Command and Conquer (1)".
# Updated "Art of War (2)".
# Updated "Pursuit of Knowledge (3)".
# Updated "Chains of Eminence (1)".
# Updated "Rusted Relic (3)".
# Updated "Life for a Life (1)".
# Updated "Life for a Life (2)".
# Updated "Life for a Life (3)".
# Updated "Enchanting Melody (1)".
# Updated "Enchanting Melody (2)".
# Updated "Enchanting Melody (3)".
# Updated "Plunder Run (1)".
# Updated "Plunder Run (2)".
# Updated "Plunder Run (3)".
# Updated "Eirina's Prayer (1)".
# Updated "Eirina's Prayer (2)".
# Updated "Eirina's Prayer (3)".
# Updated "Back Alley Breakline (1)".
# Updated "Back Alley Breakline (2)".
# Updated "Back Alley Breakline (3)".
# Updated "Cadaverous Contraband (1)".
# Updated "Cadaverous Contraband (2)".
# Updated "Cadaverous Contraband (3)".
# Updated "Fervent Forerunner (1)".
# Updated "Fervent Forerunner (2)".
# Updated "Fervent Forerunner (3)".
# Updated "Moon Wish (1)".
# Updated "Moon Wish (2)".
# Updated "Moon Wish (3)".
# Updated "Push the Point (1)".
# Updated "Push the Point (2)".
# Updated "Push the Point (3)".
# Updated "Ravenous Rabble (1)".
# Updated "Ravenous Rabble (2)".
# Updated "Ravenous Rabble (3)".
# Updated "Rifting (1)".
# Updated "Rifting (2)".
# Updated "Rifting (3)".
# Updated "Vigor Rush (1)".
# Updated "Vigor Rush (2)".
# Updated "Vigor Rush (3)".
# Updated "Fate Foreseen (1)".
# Updated "Fate Foreseen (2)".
# Updated "Fate Foreseen (3)".
# Updated "Come to Fight (1)".
# Updated "Come to Fight (2)".
# Updated "Come to Fight (3)".
# Updated "Force Sight (1)".
# Updated "Force Sight (2)".
# Updated "Force Sight (3)".
# Updated "Lead the Charge (1)".
# Updated "Lead the Charge (2)".
# Updated "Lead the Charge (3)".
# Updated "Sun Kiss (1)".
# Updated "Sun Kiss (2)".
# Updated "Sun Kiss (3)".
# Updated "Whisper of the Oracle (1)".
# Updated "Whisper of the Oracle (2)".
# Updated "Whisper of the Oracle (3)".
# Updated "Mandible Claw".
# Updated "Edge of Autumn".
# Updated "Zephyr Needle".
# Updated "Plasma Barrel Shot".
# Updated "Gorganian Tome".
# Updated "Great Library of Solana".
# Updated "Herald of Erudition (2)".
# Updated "Herald of Judgment (2)".
# Updated "Herald of Tenacity (1)".
# Updated "Herald of Tenacity (2)".
# Updated "Herald of Tenacity (3)".
# Updated "V of the Vanguard (2)".
# Updated "Dread Screamer (1)".
# Updated "Dread Screamer (2)".
# Updated "Dread Screamer (3)".
# Updated "Shadow of Ursur (3)".
# Updated "Dimenxxional Gateway (2)".
# Updated "Seeping Shadows (1)".
# Updated "Seeping Shadows (2)".
# Updated "Seeping Shadows (3)".
# Updated "Rip Through Reality (1)".
# Updated "Rip Through Reality (2)".
# Updated "Rip Through Reality (3)".
# Updated "Seeds of Agony (1)".
# Updated "Seeds of Agony (2)".
# Updated "Seeds of Agony (3)".
# Updated "Doomsday (3)".
# Updated "Soul Harvest (3)".
# Updated "Soul Reaping (1)".
# Updated "Howl from Beyond (1)".
# Updated "Howl from Beyond (2)".
# Updated "Howl from Beyond (3)".
# Updated "Ursur, the Soul Reaper".
# Updated "Korshem, Crossroad of Elements".
# Updated "Glacial Footsteps (1)".
# Updated "Glacial Footsteps (2)".
# Updated "Glacial Footsteps (3)".
# Updated "Ice Storm (1)".
# Updated "Flake Out (1)".
# Updated "Flake Out (2)".
# Updated "Flake Out (3)".
# Updated "Flashfreeze (1)".
# Updated "Entwine Ice (1)".
# Updated "Entwine Ice (2)".
# Updated "Entwine Ice (3)".
# Updated "Pulse of Candlehold (2)".
# Updated "Heart of Ice".
# Updated "Channel Lake Frigid (3)".
# Updated "Ready to Roll (3)".
# Updated "High Roller (1)".
# Updated "High Roller (2)".
# Updated "High Roller (3)".
# Updated "Bravo, Star of the Show".
# Updated "Break Tide (2)".
# Updated "Zoom In (1)".
# Updated "Zoom In (2)".
# Updated "Zoom In (3)".
# Updated "Clearing Bellow (3)".
# Added 0 cards and updated 502 cards.

# %% [markdown]
# If we feel comfortable with the changes, we re-save over their old JSON versions.

# %%
cards.save('~/work/data/cards.json')
card_sets.save('~/work/data/card-sets.json')
